# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
combined_data_df = pd.merge(study_results, mouse_metadata, how = "left", on = ["Mouse ID"])
# Display the data table for preview
combined_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
number_of_mice = combined_data_df["Mouse ID"].unique()
number_of_mice
# Out:
# array(['b128', 'f932', 'g107', 'a457', 'c819', 'h246', 'p189', 'n923',
#        'q119', 'f993', 'z234', 'b559', 'y260', 'x930', 'o725', 'z969',
#        'v835', 'r604', 'n304', 'l700', 'x336', 'l725', 'm133', 'v295',
#        'a818', 'y601', 't724', 'k382', 'w422', 'c326', 'c139', 'v339',
#        'a577', 'y163', 'k483', 'k804', 'o809', 'z581', 'a251', 'i386',
#        'c580', 'q132', 'u327', 'v603', 'f278', 'g497', 'd474', 'o973',
#        'c832', 'o331', 'm650', 'v289', 'm550', 'h428', 'r701', 'v199',
#        'x264', 'f234', 'c458', 'q610', 'j913', 'a411', 'a444', 'd251',
#        'j989', 'y449', 'k403', 'c758', 'x402', 'r811', 'a644', 'i177',
#        'g791', 'a520', 'u196', 'm546', 'w678', 'n364', 's508', 'e662',
#        'z578', 'r921', 'a492', 'w540', 'v764', 'z795', 'e291', 'e584',
#        'e213', 'j755', 's565', 'a366', 'p387', 'b879', 'i901', 'k862',
#        'g867', 's619', 'w697', 'j984', 'c402', 'h333', 'k510', 'p981',
# ...

# %%
# Getting the Mouse ID numbers that show up with duplicate Timepoints. 
duplicates = combined_data_df.loc[combined_data_df.duplicated(subset=['Mouse ID', 'Timepoint'])]
duplicates
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
# Optional: Display all the data for the duplicate mouse ID. 
duplicate_mouse_data_df = combined_data_df.loc[combined_data_df["Mouse ID"] == 'g989']
len(duplicate_mouse_data_df)
duplicate_mouse_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping all data associated with the duplicate mouse by its ID.
cleaned_df = combined_data_df.loc[combined_data_df["Mouse ID"] != "g989"]
cleaned_df["Mouse ID"].count()
# Out:
# 1880

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_df.drop_duplicates(subset="Mouse ID")["Mouse ID"].count()
len(cleaned_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume 
# for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
cleaned_df.groupby("Drug Regimen").count()
cleaned_mean = cleaned_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].mean()
cleaned_median = cleaned_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].median()
cleaned_variance = cleaned_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].var()
cleaned_standard_deviation = cleaned_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].std()
cleaned_SEM = cleaned_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].sem()

summary_table_df = pd.DataFrame({
    "Mean" : cleaned_mean,
    "Median" : cleaned_median,
    "Variance" : cleaned_variance,
    "Standard Deviation" : cleaned_standard_deviation,
    "SEM" : cleaned_SEM
})
summary_table_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume
# for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
new_summary_table_df = cleaned_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":
                                                               ["mean", "median", "var", "std", "sem"]
})
new_summary_table_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
total_measurements = cleaned_df['Drug Regimen'].value_counts()
total_measurements.plot.bar()
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")
plt.xticks(rotation=45)
plt.title("Total Number of Measurements Per Each Drug Regimen")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
total_measurements = cleaned_df['Drug Regimen'].value_counts()
plt.bar(total_measurements.index.values, total_measurements.values)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")
plt.xticks(rotation=45)
plt.title("Total Number of Measurements Per Each Drug Regimen")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

sex_distribution = cleaned_df.drop_duplicates(subset="Mouse ID")['Sex'].value_counts()
sex_distribution.plot.pie()
plt.title("Distribution of Female Versus Male Mice")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#male_sex_distribution = cleaned_df.loc[cleaned_df["Sex"] == "Male"]
#male_count = male_sex_distribution["Mouse ID"].nunique()
#female_sex_distribution = cleaned_df.loc[cleaned_df["Sex"] == "Female"]
#female_count = female_sex_distribution["Mouse ID"].nunique()
#sex_distribution = cleaned_df["Male", "Female"]
new_sex_distribution = cleaned_df.drop_duplicates(subset="Mouse ID")["Sex"].value_counts()
plt.pie(new_sex_distribution.values, labels= new_sex_distribution.index.values)
plt.title("Distribution of Female Versus Male Mice")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
final_tumor_volume = cleaned_df.groupby(["Mouse ID"]).max()
final_tumor_volume_capomulin = cleaned_df.loc[cleaned_df["Drug Regimen"] == "Capomulin"]["Tumor Volume (mm3)"]
final_tumor_volume_ramicane = cleaned_df.loc[cleaned_df["Drug Regimen"] == "Ramicane"]["Tumor Volume (mm3)"]
final_tumor_volume_infubinol = cleaned_df.loc[cleaned_df["Drug Regimen"] == "Infubinol"]["Tumor Volume (mm3)"]
final_tumor_volume_ceftamin = cleaned_df.loc[cleaned_df["Drug Regimen"] == "Ceftamin"]["Tumor Volume (mm3)"]

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_df = final_tumor_volume[["Mouse ID", "Timepoint"]].merge(cleaned_df, on=["Mouse ID", "Timepoint"], how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-b967491a6c8b> in <module>()
#       9
#      10 # Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# ---> 11 merged_df = final_tumor_volume[["Mouse ID", "Timepoint"]].merge(cleaned_df, on=["Mouse ID", "Timepoint"], how="left")
#
# C:\Users\angel\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\Users\angel\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
# ...

# %%
# Put treatments into a list for a for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
